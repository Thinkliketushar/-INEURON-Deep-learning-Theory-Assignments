# %% [markdown]
# # Assignment 07 Solutions

# %% [markdown]
# #### 1.	Can you think of a few applications for a sequence-to-sequence RNN? What about a sequence-to-vector RNN, and a vector-to-sequence RNN?

# %% [markdown]
# <code>Machine Translation, Speech Recognition, Text Summarization, Chatbots and Natural Language Generation, Image Captioning, Time Series Prediction,e tc. Feed sequence of inputs and take only last output, so it is called Sequence-to-Vector. For example, take an IMDB review of a movie and ignore all outputs in the middle to predict the movie horror or drama. Feed the same input vector multiple times at each time and produce an output, so it is called Vector-to-Sequence.

# %% [markdown]
# #### 2.	How many dimensions must the inputs of an RNN layer have? What does each dimension represent? What about its outputs?

# %% [markdown]
# <code>3 dimensions, batch size, sequence length, and input features, batch size, sequence length, and output features for 3 dimesnions as output

# %% [markdown]
# #### 3.	If you want to build a deep sequence-to-sequence RNN, which RNN layers should have return_sequences=True? What about a sequence-to-vector RNN?

# %% [markdown]
# <code>When building a deep sequence-to-sequence RNN (Recurrent Neural Network), you typically have multiple layers, and you would set return_sequences=True for all the recurrent layers. This is necessary to ensure that each RNN layer in the stack produces an output sequence that can be used as input for the next layer in the stack.
# In contrast, for a sequence-to-vector RNN, you typically set return_sequences=False (or you can omit it because it's often the default behavior). This configuration means that the final output of the RNN will be a single vector summarizing the entire input sequence.

# %% [markdown]
# #### 4.	Suppose you have a daily univariate time series, and you want to forecast the next seven days. Which RNN architecture should you use?

# %% [markdown]
# <code>Encoder-Decoder or Sequence-to-Sequence

# %% [markdown]
# #### 5.	What are the main difficulties when training RNNs? How can you handle them?

# %% [markdown]
# <code> Vanishing & Exploding Gradients, Long Training Times, Overfitting, Data Preprocessing, hoosing the Right Architecture and Hyperparameters, etc.

# %% [markdown]
# #### 6.	Can you sketch the LSTM cell’s architecture?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 7.	Why would you want to use 1D convolutional layers in an RNN?

# %% [markdown]
# <code>Dimensionality Reduction, Local Pattern Detection, Reducing Vanishing Gradient Problems, Feature Extraction.

# %% [markdown]
# #### 8.	Which neural network architecture could you use to classify videos?

# %% [markdown]
# <code>RNN, convlstm, 3d CNN, etc.

# %% [markdown]
# #### 9.	Train a classification model for the SketchRNN dataset, available in TensorFlow Datasets.

# %%
#dataset not found
